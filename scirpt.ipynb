# %% [markdown]
# <a href="https://colab.research.google.com/github/andreborgezz/python-tabela-de-vendas/blob/main/scirpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
